# %% [markdown]
# <a href="https://colab.research.google.com/github/jklee16/167-Notebook-Repo/blob/main/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-qkvafuqn
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-qkvafuqn
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=b0fb60f9f2cfc21788b240bb08f5fbd25ad446d4100d1d730c44f3400ae7163f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f2e_ivu0/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# Done:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1. At what capacity do you think the training error will become zero?
# 2. At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# #ANSWERS
# 1. I think that the capacity would need to be closer to 4000 for the training error to become zero, as the training would match the test examples.
# 2. I expect that the first minima to be around 22.
# 3. I think the maximum will occur at around 50.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302927, train error 90.03,  test loss 2.303158, test error 89.78
# Epoch   100, train loss 2.006631, train error 76.40,  test loss 1.912451, test error 75.18
# Epoch   200, train loss 1.908438, train error 71.78,  test loss 1.753613, test error 69.00
# Epoch   300, train loss 1.904250, train error 71.82,  test loss 1.740675, test error 69.62
# Epoch   400, train loss 1.908657, train error 70.97,  test loss 1.755783, test error 69.65
# Epoch   500, train loss 1.903033, train error 70.90,  test loss 1.736735, test error 69.15
# Epoch   600, train loss 1.902340, train error 71.05,  test loss 1.742979, test error 69.60
# Epoch   700, train loss 1.906494, train error 71.28,  test loss 1.751412, test error 69.35
# Epoch   800, train loss 1.902230, train error 70.93,  test loss 1.740171, test error 70.00
# Epoch   900, train loss 1.902779, train error 70.40,  test loss 1.743034, test error 69.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.308795, train error 90.32,  test loss 2.310957, test error 90.57
# Epoch   100, train loss 1.863146, train error 70.38,  test loss 1.720885, test error 68.35
# Epoch   200, train loss 1.750480, train error 63.30,  test loss 1.568680, test error 60.35
# Epoch   300, train loss 1.750853, train error 63.10,  test loss 1.567638, test error 61.60
# Epoch   400, train loss 1.727159, train error 62.50,  test loss 1.533544, test error 59.08
# Epoch   500, train loss 1.716878, train error 62.08,  test loss 1.526446, test error 59.50
# Epoch   600, train loss 1.723225, train error 63.92,  test loss 1.537897, test error 59.80
# Epoch   700, train loss 1.707810, train error 61.88,  test loss 1.520764, test error 58.78
# Epoch   800, train loss 1.705899, train error 62.25,  test loss 1.520423, test error 59.15
# Epoch   900, train loss 1.710796, train error 63.25,  test loss 1.538003, test error 60.40
# Training model with   6 hidden variables
# Epoch     0, train loss 2.315111, train error 88.03,  test loss 2.310743, test error 89.35
# Epoch   100, train loss 1.604897, train error 55.35,  test loss 1.413098, test error 52.67
# Epoch   200, train loss 1.600818, train error 55.30,  test loss 1.400915, test error 53.08
# Epoch   300, train loss 1.579362, train error 54.28,  test loss 1.398358, test error 51.40
# Epoch   400, train loss 1.568811, train error 53.90,  test loss 1.386778, test error 51.78
# Epoch   500, train loss 1.564578, train error 54.03,  test loss 1.381288, test error 51.50
# Epoch   600, train loss 1.563436, train error 53.90,  test loss 1.384410, test error 50.67
# Epoch   700, train loss 1.551521, train error 53.65,  test loss 1.377764, test error 51.35
# Epoch   800, train loss 1.543988, train error 54.00,  test loss 1.369956, test error 51.78
# Epoch   900, train loss 1.546585, train error 54.12,  test loss 1.378441, test error 52.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.174398, train error 81.53,  test loss 2.155055, test error 82.68
# Epoch   100, train loss 1.609334, train error 57.78,  test loss 1.444332, test error 56.72
# Epoch   200, train loss 1.568351, train error 56.00,  test loss 1.425199, test error 54.60
# Epoch   300, train loss 1.553838, train error 55.95,  test loss 1.426254, test error 54.47
# Epoch   400, train loss 1.547355, train error 55.67,  test loss 1.432460, test error 55.55
# Epoch   500, train loss 1.541921, train error 54.75,  test loss 1.439921, test error 55.35
# Epoch   600, train loss 1.535970, train error 54.70,  test loss 1.429290, test error 55.47
# Epoch   700, train loss 1.531363, train error 53.85,  test loss 1.427744, test error 55.58
# Epoch   800, train loss 1.528469, train error 54.67,  test loss 1.433491, test error 55.60
# Epoch   900, train loss 1.528533, train error 54.33,  test loss 1.430552, test error 55.03
# Training model with  10 hidden variables
# Epoch     0, train loss 2.306518, train error 88.30,  test loss 2.309338, test error 88.65
# Epoch   100, train loss 1.493040, train error 50.58,  test loss 1.339029, test error 48.30
# Epoch   200, train loss 1.415010, train error 48.05,  test loss 1.272311, test error 46.45
# Epoch   300, train loss 1.386498, train error 46.65,  test loss 1.261743, test error 46.47
# Epoch   400, train loss 1.377072, train error 46.33,  test loss 1.258414, test error 46.88
# Epoch   500, train loss 1.367667, train error 45.80,  test loss 1.263913, test error 46.88
# Epoch   600, train loss 1.360079, train error 46.30,  test loss 1.266882, test error 47.08
# Epoch   700, train loss 1.359004, train error 45.08,  test loss 1.281328, test error 47.25
# Epoch   800, train loss 1.355412, train error 45.35,  test loss 1.286088, test error 47.05
# Epoch   900, train loss 1.353301, train error 45.00,  test loss 1.287280, test error 47.28
# Training model with  14 hidden variables
# Epoch     0, train loss 2.170505, train error 81.82,  test loss 2.138469, test error 80.07
# Epoch   100, train loss 1.414242, train error 48.83,  test loss 1.317412, test error 49.92
# Epoch   200, train loss 1.334855, train error 44.53,  test loss 1.286631, test error 47.50
# Epoch   300, train loss 1.291647, train error 43.50,  test loss 1.291931, test error 47.58
# Epoch   400, train loss 1.281961, train error 43.90,  test loss 1.323330, test error 48.97
# Epoch   500, train loss 1.263661, train error 42.88,  test loss 1.338012, test error 48.55
# Epoch   600, train loss 1.255823, train error 44.00,  test loss 1.356080, test error 49.20
# Epoch   700, train loss 1.252021, train error 43.22,  test loss 1.387900, test error 49.38
# Epoch   800, train loss 1.241818, train error 43.22,  test loss 1.391889, test error 48.58
# Epoch   900, train loss 1.239138, train error 42.78,  test loss 1.404252, test error 49.80
# Training model with  18 hidden variables
# Epoch     0, train loss 2.162663, train error 80.80,  test loss 2.133411, test error 78.68
# Epoch   100, train loss 1.357658, train error 45.88,  test loss 1.339115, test error 50.83
# Epoch   200, train loss 1.246463, train error 41.50,  test loss 1.354352, test error 49.40
# Epoch   300, train loss 1.199252, train error 40.88,  test loss 1.409652, test error 49.78
# Epoch   400, train loss 1.178517, train error 40.12,  test loss 1.466376, test error 50.47
# Epoch   500, train loss 1.151811, train error 38.97,  test loss 1.487622, test error 50.38
# Epoch   600, train loss 1.141281, train error 38.55,  test loss 1.523388, test error 50.55
# Epoch   700, train loss 1.126264, train error 37.75,  test loss 1.537427, test error 50.58
# Epoch   800, train loss 1.111526, train error 37.45,  test loss 1.577886, test error 51.55
# Epoch   900, train loss 1.112018, train error 37.58,  test loss 1.594443, test error 51.92
# Training model with  22 hidden variables
# Epoch     0, train loss 2.183482, train error 81.25,  test loss 2.159798, test error 79.90
# Epoch   100, train loss 1.287443, train error 42.80,  test loss 1.327214, test error 49.20
# Epoch   200, train loss 1.156486, train error 37.85,  test loss 1.348548, test error 49.83
# Epoch   300, train loss 1.094484, train error 36.10,  test loss 1.377138, test error 48.88
# Epoch   400, train loss 1.050607, train error 34.60,  test loss 1.447965, test error 50.50
# Epoch   500, train loss 1.035184, train error 34.45,  test loss 1.508770, test error 50.95
# Epoch   600, train loss 1.013975, train error 33.43,  test loss 1.567772, test error 51.58
# Epoch   700, train loss 0.993107, train error 33.45,  test loss 1.630650, test error 51.80
# Epoch   800, train loss 0.972868, train error 33.15,  test loss 1.675030, test error 52.17
# Epoch   900, train loss 0.968124, train error 33.25,  test loss 1.722016, test error 52.62
# Training model with  26 hidden variables
# Epoch     0, train loss 2.172527, train error 80.53,  test loss 2.129038, test error 79.78
# Epoch   100, train loss 1.221111, train error 40.42,  test loss 1.350437, test error 50.67
# Epoch   200, train loss 1.048023, train error 35.53,  test loss 1.473548, test error 52.03
# Epoch   300, train loss 0.969123, train error 32.72,  test loss 1.605252, test error 53.20
# Epoch   400, train loss 0.913298, train error 31.18,  test loss 1.744504, test error 54.50
# Epoch   500, train loss 0.898687, train error 30.88,  test loss 1.836253, test error 55.28
# Epoch   600, train loss 0.876198, train error 31.10,  test loss 1.972941, test error 56.40
# Epoch   700, train loss 0.856551, train error 30.20,  test loss 2.022221, test error 55.90
# Epoch   800, train loss 0.828423, train error 29.35,  test loss 2.090923, test error 56.60
# Epoch   900, train loss 0.821048, train error 28.95,  test loss 2.159864, test error 56.33
# Training model with  30 hidden variables
# Epoch     0, train loss 2.205474, train error 81.62,  test loss 2.176568, test error 81.40
# Epoch   100, train loss 1.112667, train error 36.65,  test loss 1.324389, test error 48.92
# Epoch   200, train loss 0.944137, train error 31.00,  test loss 1.491119, test error 49.30
# Epoch   300, train loss 0.837563, train error 27.50,  test loss 1.666179, test error 50.83
# Epoch   400, train loss 0.780647, train error 25.25,  test loss 1.839453, test error 51.38
# Epoch   500, train loss 0.743159, train error 24.55,  test loss 1.998418, test error 51.90
# Epoch   600, train loss 0.711281, train error 23.03,  test loss 2.150570, test error 53.15
# Epoch   700, train loss 0.702911, train error 23.40,  test loss 2.263214, test error 53.78
# Epoch   800, train loss 0.682893, train error 23.15,  test loss 2.452648, test error 54.90
# Epoch   900, train loss 0.657999, train error 22.50,  test loss 2.494205, test error 54.40
# Training model with  35 hidden variables
# Epoch     0, train loss 2.096501, train error 78.90,  test loss 2.078133, test error 78.97
# Epoch   100, train loss 1.024408, train error 33.00,  test loss 1.387216, test error 49.17
# Epoch   200, train loss 0.779429, train error 25.15,  test loss 1.686544, test error 50.90
# Epoch   300, train loss 0.675549, train error 21.10,  test loss 1.985495, test error 52.20
# Epoch   400, train loss 0.589970, train error 18.95,  test loss 2.374686, test error 54.00
# Epoch   500, train loss 0.553948, train error 18.53,  test loss 2.833186, test error 54.75
# Epoch   600, train loss 0.498467, train error 16.75,  test loss 3.149550, test error 55.17
# Epoch   700, train loss 0.564653, train error 19.95,  test loss 3.551245, test error 56.15
# Epoch   800, train loss 0.457204, train error 15.45,  test loss 3.731295, test error 55.42
# Epoch   900, train loss 0.463955, train error 15.80,  test loss 4.020729, test error 56.10
# Training model with  40 hidden variables
# Epoch     0, train loss 2.139004, train error 79.53,  test loss 2.119574, test error 79.15
# Epoch   100, train loss 0.902372, train error 28.65,  test loss 1.402541, test error 48.58
# Epoch   200, train loss 0.603314, train error 19.82,  test loss 1.967559, test error 51.92
# Epoch   300, train loss 0.449452, train error 14.50,  test loss 2.668132, test error 53.22
# Epoch   400, train loss 0.368128, train error 12.22,  test loss 3.486717, test error 53.50
# Epoch   500, train loss 0.301360, train error 10.15,  test loss 4.228507, test error 54.10
# Epoch   600, train loss 0.296809, train error 10.75,  test loss 4.982240, test error 54.30
# Epoch   700, train loss 0.249566, train error 9.10,  test loss 5.765759, test error 55.12
# Epoch   800, train loss 0.241981, train error 8.70,  test loss 6.471695, test error 55.38
# Epoch   900, train loss 0.248956, train error 8.38,  test loss 7.139970, test error 55.53
# Training model with  45 hidden variables
# Epoch     0, train loss 2.113408, train error 78.18,  test loss 2.072934, test error 76.97
# Epoch   100, train loss 0.840456, train error 26.12,  test loss 1.431243, test error 49.62
# Epoch   200, train loss 0.496348, train error 16.05,  test loss 2.109310, test error 51.50
# Epoch   300, train loss 0.306786, train error 9.22,  test loss 3.127605, test error 54.15
# Epoch   400, train loss 0.238735, train error 7.93,  test loss 4.406988, test error 54.50
# Epoch   500, train loss 0.176300, train error 6.30,  test loss 5.649079, test error 55.53
# Epoch   600, train loss 0.144730, train error 5.12,  test loss 6.848208, test error 56.75
# Epoch   700, train loss 0.014573, train error 0.00,  test loss 7.976152, test error 56.60
# Epoch   800, train loss 0.009292, train error 0.00,  test loss 8.690315, test error 56.83
# Epoch   900, train loss 0.006848, train error 0.00,  test loss 9.227324, test error 56.97
# Training model with  50 hidden variables
# Epoch     0, train loss 2.100207, train error 78.07,  test loss 2.043558, test error 77.35
# Epoch   100, train loss 0.750069, train error 22.82,  test loss 1.573136, test error 50.22
# Epoch   200, train loss 0.347603, train error 9.97,  test loss 2.691153, test error 54.58
# Epoch   300, train loss 0.157408, train error 3.43,  test loss 4.407934, test error 56.30
# Epoch   400, train loss 0.031475, train error 0.03,  test loss 6.078465, test error 57.03
# Epoch   500, train loss 0.013820, train error 0.00,  test loss 7.118044, test error 56.85
# Epoch   600, train loss 0.008730, train error 0.00,  test loss 7.819992, test error 57.15
# Epoch   700, train loss 0.006242, train error 0.00,  test loss 8.313776, test error 57.25
# Epoch   800, train loss 0.004762, train error 0.00,  test loss 8.707813, test error 57.38
# Epoch   900, train loss 0.003849, train error 0.00,  test loss 9.044594, test error 57.40
# Training model with  55 hidden variables
# Epoch     0, train loss 2.033770, train error 75.55,  test loss 1.981949, test error 76.15
# Epoch   100, train loss 0.606993, train error 18.62,  test loss 1.656815, test error 51.10
# Epoch   200, train loss 0.188085, train error 4.30,  test loss 3.015857, test error 53.05
# Epoch   300, train loss 0.035344, train error 0.07,  test loss 4.699311, test error 54.45
# Epoch   400, train loss 0.013399, train error 0.00,  test loss 5.656958, test error 54.33
# Epoch   500, train loss 0.007874, train error 0.00,  test loss 6.256906, test error 54.70
# Epoch   600, train loss 0.005487, train error 0.00,  test loss 6.687081, test error 54.83
# Epoch   700, train loss 0.004110, train error 0.00,  test loss 7.027652, test error 55.08
# Epoch   800, train loss 0.003270, train error 0.00,  test loss 7.300349, test error 55.00
# Epoch   900, train loss 0.002684, train error 0.00,  test loss 7.525990, test error 54.90
# Training model with  60 hidden variables
# Epoch     0, train loss 2.079911, train error 76.12,  test loss 2.031121, test error 75.20
# Epoch   100, train loss 0.573233, train error 18.03,  test loss 1.673400, test error 51.22
# Epoch   200, train loss 0.126415, train error 2.15,  test loss 3.186635, test error 53.92
# Epoch   300, train loss 0.021934, train error 0.00,  test loss 4.570513, test error 54.40
# Epoch   400, train loss 0.009931, train error 0.00,  test loss 5.277704, test error 54.22
# Epoch   500, train loss 0.006193, train error 0.00,  test loss 5.728087, test error 54.10
# Epoch   600, train loss 0.004413, train error 0.00,  test loss 6.069923, test error 54.25
# Epoch   700, train loss 0.003393, train error 0.00,  test loss 6.336434, test error 54.17
# Epoch   800, train loss 0.002712, train error 0.00,  test loss 6.558692, test error 54.38
# Epoch   900, train loss 0.002250, train error 0.00,  test loss 6.748718, test error 54.35
# Training model with  70 hidden variables
# Epoch     0, train loss 2.056735, train error 75.78,  test loss 1.997120, test error 75.38
# Epoch   100, train loss 0.348833, train error 8.30,  test loss 1.953745, test error 51.15
# Epoch   200, train loss 0.031120, train error 0.00,  test loss 3.653615, test error 54.05
# Epoch   300, train loss 0.010660, train error 0.00,  test loss 4.434916, test error 54.12
# Epoch   400, train loss 0.005920, train error 0.00,  test loss 4.874092, test error 54.10
# Epoch   500, train loss 0.004000, train error 0.00,  test loss 5.174499, test error 54.03
# Epoch   600, train loss 0.002970, train error 0.00,  test loss 5.413373, test error 53.92
# Epoch   700, train loss 0.002335, train error 0.00,  test loss 5.600925, test error 53.75
# Epoch   800, train loss 0.001913, train error 0.00,  test loss 5.756736, test error 53.80
# Epoch   900, train loss 0.001611, train error 0.00,  test loss 5.893730, test error 53.78
# Training model with  80 hidden variables
# Epoch     0, train loss 1.971588, train error 73.40,  test loss 1.908136, test error 73.18
# Epoch   100, train loss 0.249329, train error 5.10,  test loss 2.057971, test error 52.15
# Epoch   200, train loss 0.020964, train error 0.00,  test loss 3.373466, test error 52.08
# Epoch   300, train loss 0.008275, train error 0.00,  test loss 3.920744, test error 51.97
# Epoch   400, train loss 0.004875, train error 0.00,  test loss 4.255551, test error 52.12
# Epoch   500, train loss 0.003349, train error 0.00,  test loss 4.487800, test error 51.88
# Epoch   600, train loss 0.002513, train error 0.00,  test loss 4.670253, test error 52.05
# Epoch   700, train loss 0.001990, train error 0.00,  test loss 4.819812, test error 51.97
# Epoch   800, train loss 0.001636, train error 0.00,  test loss 4.942314, test error 52.00
# Epoch   900, train loss 0.001383, train error 0.00,  test loss 5.049723, test error 51.95
# Training model with  90 hidden variables
# Epoch     0, train loss 1.995202, train error 75.53,  test loss 1.929872, test error 75.30
# Epoch   100, train loss 0.152423, train error 1.55,  test loss 2.248231, test error 53.50
# Epoch   200, train loss 0.015555, train error 0.00,  test loss 3.318223, test error 53.22
# Epoch   300, train loss 0.006709, train error 0.00,  test loss 3.763329, test error 53.00
# Epoch   400, train loss 0.004083, train error 0.00,  test loss 4.050341, test error 53.03
# Epoch   500, train loss 0.002869, train error 0.00,  test loss 4.252131, test error 53.12
# Epoch   600, train loss 0.002179, train error 0.00,  test loss 4.408156, test error 53.10
# Epoch   700, train loss 0.001743, train error 0.00,  test loss 4.536368, test error 53.05
# Epoch   800, train loss 0.001441, train error 0.00,  test loss 4.647108, test error 53.00
# Epoch   900, train loss 0.001223, train error 0.00,  test loss 4.740827, test error 53.03
# Training model with 100 hidden variables
# Epoch     0, train loss 1.993323, train error 73.65,  test loss 1.930172, test error 74.32
# Epoch   100, train loss 0.093132, train error 0.30,  test loss 2.254513, test error 50.22
# Epoch   200, train loss 0.012148, train error 0.00,  test loss 3.054760, test error 50.28
# Epoch   300, train loss 0.005659, train error 0.00,  test loss 3.418995, test error 50.47
# Epoch   400, train loss 0.003550, train error 0.00,  test loss 3.645766, test error 50.20
# Epoch   500, train loss 0.002522, train error 0.00,  test loss 3.811022, test error 50.08
# Epoch   600, train loss 0.001931, train error 0.00,  test loss 3.940749, test error 50.12
# Epoch   700, train loss 0.001552, train error 0.00,  test loss 4.045989, test error 50.10
# Epoch   800, train loss 0.001290, train error 0.00,  test loss 4.136872, test error 50.17
# Epoch   900, train loss 0.001098, train error 0.00,  test loss 4.216256, test error 50.30
# Training model with 120 hidden variables
# Epoch     0, train loss 1.979030, train error 73.68,  test loss 1.875956, test error 72.45
# Epoch   100, train loss 0.051002, train error 0.00,  test loss 2.186316, test error 49.62
# Epoch   200, train loss 0.009495, train error 0.00,  test loss 2.800946, test error 50.08
# Epoch   300, train loss 0.004668, train error 0.00,  test loss 3.076910, test error 49.78
# Epoch   400, train loss 0.002990, train error 0.00,  test loss 3.256792, test error 49.95
# Epoch   500, train loss 0.002155, train error 0.00,  test loss 3.386441, test error 50.03
# Epoch   600, train loss 0.001664, train error 0.00,  test loss 3.490684, test error 49.92
# Epoch   700, train loss 0.001346, train error 0.00,  test loss 3.577203, test error 49.92
# Epoch   800, train loss 0.001123, train error 0.00,  test loss 3.650527, test error 50.00
# Epoch   900, train loss 0.000959, train error 0.00,  test loss 3.714516, test error 49.97
# Training model with 140 hidden variables
# Epoch     0, train loss 1.951309, train error 72.07,  test loss 1.889629, test error 72.00
# Epoch   100, train loss 0.033690, train error 0.00,  test loss 2.102763, test error 48.70
# Epoch   200, train loss 0.007810, train error 0.00,  test loss 2.559635, test error 48.38
# Epoch   300, train loss 0.004035, train error 0.00,  test loss 2.782125, test error 48.50
# Epoch   400, train loss 0.002629, train error 0.00,  test loss 2.923008, test error 48.72
# Epoch   500, train loss 0.001918, train error 0.00,  test loss 3.029509, test error 48.62
# Epoch   600, train loss 0.001493, train error 0.00,  test loss 3.115324, test error 48.55
# Epoch   700, train loss 0.001214, train error 0.00,  test loss 3.186561, test error 48.60
# Epoch   800, train loss 0.001017, train error 0.00,  test loss 3.246464, test error 48.47
# Epoch   900, train loss 0.000873, train error 0.00,  test loss 3.298469, test error 48.55
# Training model with 160 hidden variables
# Epoch     0, train loss 1.925655, train error 71.20,  test loss 1.858075, test error 73.05
# Epoch   100, train loss 0.029762, train error 0.00,  test loss 2.087270, test error 48.22
# Epoch   200, train loss 0.007322, train error 0.00,  test loss 2.491772, test error 48.83
# Epoch   300, train loss 0.003854, train error 0.00,  test loss 2.694885, test error 48.92
# Epoch   400, train loss 0.002533, train error 0.00,  test loss 2.830912, test error 49.08
# Epoch   500, train loss 0.001854, train error 0.00,  test loss 2.930654, test error 49.05
# Epoch   600, train loss 0.001447, train error 0.00,  test loss 3.011695, test error 49.05
# Epoch   700, train loss 0.001177, train error 0.00,  test loss 3.077964, test error 49.12
# Epoch   800, train loss 0.000987, train error 0.00,  test loss 3.135460, test error 49.08
# Epoch   900, train loss 0.000847, train error 0.00,  test loss 3.185680, test error 49.15
# Training model with 180 hidden variables
# Epoch     0, train loss 1.933728, train error 71.60,  test loss 1.853039, test error 72.65
# Epoch   100, train loss 0.024473, train error 0.00,  test loss 2.161743, test error 49.53
# Epoch   200, train loss 0.006549, train error 0.00,  test loss 2.544609, test error 49.47
# Epoch   300, train loss 0.003519, train error 0.00,  test loss 2.735289, test error 49.60
# Epoch   400, train loss 0.002331, train error 0.00,  test loss 2.863515, test error 49.72
# Epoch   500, train loss 0.001716, train error 0.00,  test loss 2.959869, test error 49.78
# Epoch   600, train loss 0.001343, train error 0.00,  test loss 3.036299, test error 49.75
# Epoch   700, train loss 0.001097, train error 0.00,  test loss 3.100684, test error 49.78
# Epoch   800, train loss 0.000922, train error 0.00,  test loss 3.155458, test error 49.83
# Epoch   900, train loss 0.000793, train error 0.00,  test loss 3.203502, test error 49.75
# Training model with 200 hidden variables
# Epoch     0, train loss 1.903703, train error 69.78,  test loss 1.819466, test error 70.65
# Epoch   100, train loss 0.021564, train error 0.00,  test loss 2.051763, test error 49.00
# Epoch   200, train loss 0.006110, train error 0.00,  test loss 2.375323, test error 48.53
# Epoch   300, train loss 0.003309, train error 0.00,  test loss 2.541033, test error 48.38
# Epoch   400, train loss 0.002208, train error 0.00,  test loss 2.653810, test error 48.30
# Epoch   500, train loss 0.001630, train error 0.00,  test loss 2.738075, test error 48.22
# Epoch   600, train loss 0.001281, train error 0.00,  test loss 2.805587, test error 48.15
# Epoch   700, train loss 0.001047, train error 0.00,  test loss 2.861509, test error 48.15
# Epoch   800, train loss 0.000882, train error 0.00,  test loss 2.909787, test error 48.05
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.951505, test error 47.97
# Training model with 250 hidden variables
# Epoch     0, train loss 1.898955, train error 68.15,  test loss 1.831846, test error 71.00
# Epoch   100, train loss 0.016798, train error 0.00,  test loss 1.973558, test error 47.42
# Epoch   200, train loss 0.005334, train error 0.00,  test loss 2.235594, test error 47.40
# Epoch   300, train loss 0.002974, train error 0.00,  test loss 2.374540, test error 47.22
# Epoch   400, train loss 0.002010, train error 0.00,  test loss 2.468900, test error 47.25
# Epoch   500, train loss 0.001495, train error 0.00,  test loss 2.540320, test error 47.17
# Epoch   600, train loss 0.001180, train error 0.00,  test loss 2.598091, test error 47.17
# Epoch   700, train loss 0.000969, train error 0.00,  test loss 2.646671, test error 47.10
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.687980, test error 47.20
# Epoch   900, train loss 0.000705, train error 0.00,  test loss 2.724275, test error 47.10
# Training model with 300 hidden variables
# Epoch     0, train loss 1.882158, train error 68.40,  test loss 1.805402, test error 70.32
# Epoch   100, train loss 0.014423, train error 0.00,  test loss 1.848825, test error 46.42
# Epoch   200, train loss 0.004785, train error 0.00,  test loss 2.060225, test error 46.42
# Epoch   300, train loss 0.002711, train error 0.00,  test loss 2.176028, test error 46.17
# Epoch   400, train loss 0.001845, train error 0.00,  test loss 2.258079, test error 46.22
# Epoch   500, train loss 0.001381, train error 0.00,  test loss 2.318927, test error 46.10
# Epoch   600, train loss 0.001094, train error 0.00,  test loss 2.368297, test error 46.00
# Epoch   700, train loss 0.000901, train error 0.00,  test loss 2.410590, test error 45.95
# Epoch   800, train loss 0.000762, train error 0.00,  test loss 2.446165, test error 45.92
# Epoch   900, train loss 0.000659, train error 0.00,  test loss 2.477798, test error 45.90
# Training model with 400 hidden variables
# Epoch     0, train loss 1.839459, train error 64.97,  test loss 1.768455, test error 67.22
# Epoch   100, train loss 0.011559, train error 0.00,  test loss 1.770142, test error 46.67
# Epoch   200, train loss 0.004126, train error 0.00,  test loss 1.941374, test error 46.55
# Epoch   300, train loss 0.002393, train error 0.00,  test loss 2.037417, test error 46.53
# Epoch   400, train loss 0.001649, train error 0.00,  test loss 2.104802, test error 46.38
# Epoch   500, train loss 0.001243, train error 0.00,  test loss 2.156497, test error 46.42
# Epoch   600, train loss 0.000990, train error 0.00,  test loss 2.198330, test error 46.28
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.233904, test error 46.15
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.264498, test error 46.15
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.291496, test error 46.15

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
