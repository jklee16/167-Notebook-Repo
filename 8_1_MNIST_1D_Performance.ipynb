# %% [markdown]
# <a href="https://colab.research.google.com/github/jklee16/167-Notebook-Repo/blob/main/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# Done
# Define a model with two hidden layers of size 100
# And ReLU activations between them
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # Done
  # Initialize the parameters with He initialization
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.498383, train error 57.67,  test loss 1.565337, test error 62.80
# Epoch     1, train loss 1.267686, train error 47.38,  test loss 1.393044, test error 55.50
# Epoch     2, train loss 1.124940, train error 41.10,  test loss 1.302789, test error 51.70
# Epoch     3, train loss 0.997019, train error 36.58,  test loss 1.224294, test error 49.20
# Epoch     4, train loss 0.898927, train error 32.15,  test loss 1.164694, test error 45.20
# Epoch     5, train loss 0.778658, train error 26.97,  test loss 1.107154, test error 42.80
# Epoch     6, train loss 0.687510, train error 23.45,  test loss 1.046500, test error 41.10
# Epoch     7, train loss 0.716853, train error 25.45,  test loss 1.156719, test error 43.30
# Epoch     8, train loss 0.580909, train error 19.43,  test loss 1.057712, test error 39.20
# Epoch     9, train loss 0.508298, train error 16.80,  test loss 1.043373, test error 39.70
# Epoch    10, train loss 0.401968, train error 11.43,  test loss 0.988757, test error 35.90
# Epoch    11, train loss 0.374457, train error 10.97,  test loss 1.001311, test error 35.80
# Epoch    12, train loss 0.343825, train error 9.60,  test loss 1.035119, test error 37.30
# Epoch    13, train loss 0.307897, train error 7.90,  test loss 1.010461, test error 35.60
# Epoch    14, train loss 0.284417, train error 7.32,  test loss 1.048671, test error 36.50
# Epoch    15, train loss 0.258258, train error 6.28,  test loss 1.042988, test error 36.20
# Epoch    16, train loss 0.229511, train error 4.43,  test loss 1.059820, test error 35.00
# Epoch    17, train loss 0.208195, train error 3.72,  test loss 1.079993, test error 35.20
# Epoch    18, train loss 0.200122, train error 4.43,  test loss 1.106920, test error 35.20
# Epoch    19, train loss 0.186139, train error 3.75,  test loss 1.151384, test error 36.20
# Epoch    20, train loss 0.148735, train error 1.40,  test loss 1.092774, test error 35.00
# Epoch    21, train loss 0.139027, train error 1.28,  test loss 1.113535, test error 34.70
# Epoch    22, train loss 0.131533, train error 1.03,  test loss 1.127455, test error 34.40
# Epoch    23, train loss 0.124162, train error 0.90,  test loss 1.128856, test error 34.90
# Epoch    24, train loss 0.118016, train error 0.85,  test loss 1.152811, test error 34.80
# Epoch    25, train loss 0.113602, train error 0.62,  test loss 1.161090, test error 34.10
# Epoch    26, train loss 0.110381, train error 0.70,  test loss 1.182134, test error 34.80
# Epoch    27, train loss 0.099455, train error 0.45,  test loss 1.176365, test error 34.60
# Epoch    28, train loss 0.096022, train error 0.45,  test loss 1.188705, test error 33.90
# Epoch    29, train loss 0.090088, train error 0.30,  test loss 1.209710, test error 35.10
# Epoch    30, train loss 0.085499, train error 0.30,  test loss 1.203490, test error 34.20
# Epoch    31, train loss 0.083554, train error 0.30,  test loss 1.206672, test error 34.30
# Epoch    32, train loss 0.081651, train error 0.25,  test loss 1.208964, test error 34.20
# Epoch    33, train loss 0.079365, train error 0.25,  test loss 1.217982, test error 34.50
# Epoch    34, train loss 0.077670, train error 0.20,  test loss 1.223022, test error 34.70
# Epoch    35, train loss 0.075450, train error 0.25,  test loss 1.229332, test error 34.70
# Epoch    36, train loss 0.073693, train error 0.15,  test loss 1.239988, test error 34.60
# Epoch    37, train loss 0.071876, train error 0.12,  test loss 1.242849, test error 34.40
# Epoch    38, train loss 0.070158, train error 0.10,  test loss 1.246759, test error 34.60
# Epoch    39, train loss 0.068737, train error 0.10,  test loss 1.251588, test error 34.00
# Epoch    40, train loss 0.067574, train error 0.07,  test loss 1.255990, test error 34.60
# Epoch    41, train loss 0.067054, train error 0.15,  test loss 1.254964, test error 34.60
# Epoch    42, train loss 0.065838, train error 0.05,  test loss 1.259135, test error 34.50
# Epoch    43, train loss 0.065128, train error 0.05,  test loss 1.263083, test error 34.80
# Epoch    44, train loss 0.064625, train error 0.07,  test loss 1.263089, test error 34.60
# Epoch    45, train loss 0.063843, train error 0.03,  test loss 1.264582, test error 34.40
# Epoch    46, train loss 0.063072, train error 0.10,  test loss 1.266949, test error 34.40
# Epoch    47, train loss 0.062314, train error 0.03,  test loss 1.272064, test error 34.60
# Epoch    48, train loss 0.061687, train error 0.03,  test loss 1.274380, test error 34.60
# Epoch    49, train loss 0.061015, train error 0.03,  test loss 1.276649, test error 34.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **Done**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %% [markdown]
# #Answer
# Definitely not, there are so many hyperparameters that are effecting the data, that it is not effective in estimating the test performance. It is more ideal to use an optimizer or have some way to normalize the data to lower high error rates and loss.
