# %% [markdown]
# <a href="https://colab.research.google.com/github/jklee16/167-Notebook-Repo/blob/main/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-yi1ivfwa
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-yi1ivfwa
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1fe39265cac3a7fc9937665118bc2b26667ef6163254cad4cde255787ca2fea8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ineek5zn/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# Done Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

D_i1 = 1
D_o2 = 15
CV_3_2_1 = torch.nn.Conv1d(D_i1, D_o2, kernel_size=3, stride=2, padding=0)
nn.ReLU()

D_i2 = 15
D_o3 = 15
CV_3_2_2 = torch.nn.Conv1d(D_i2, D_o3, kernel_size=3, stride=2, padding=0)
nn.ReLU()

D_i3 = 15
D_o4 = 15
CV_3_2_3 = torch.nn.Conv1d(D_i3, D_o4, kernel_size=3, stride=2, padding=0)
nn.ReLU()
nn.Flatten()

nn.Linear(60, 10)


# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.
# Out:
# Linear(in_features=60, out_features=10, bias=True)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.582101, train error 61.08,  val loss 1.659067, percent error 66.00
# Epoch     1, train loss 1.303197, train error 48.45,  val loss 1.466160, percent error 57.00
# Epoch     2, train loss 1.147889, train error 42.10,  val loss 1.331835, percent error 52.50
# Epoch     3, train loss 1.011476, train error 35.97,  val loss 1.266170, percent error 50.40
# Epoch     4, train loss 0.891593, train error 31.35,  val loss 1.201323, percent error 46.10
# Epoch     5, train loss 0.781034, train error 26.10,  val loss 1.129030, percent error 42.70
# Epoch     6, train loss 0.712061, train error 24.85,  val loss 1.174016, percent error 45.10
# Epoch     7, train loss 0.678375, train error 24.43,  val loss 1.165037, percent error 44.30
# Epoch     8, train loss 0.602996, train error 21.45,  val loss 1.094026, percent error 41.70
# Epoch     9, train loss 0.497853, train error 16.45,  val loss 1.101263, percent error 39.70
# Epoch    10, train loss 0.454537, train error 14.53,  val loss 1.119856, percent error 40.50
# Epoch    11, train loss 0.439833, train error 15.28,  val loss 1.151870, percent error 39.30
# Epoch    12, train loss 0.406558, train error 14.15,  val loss 1.211527, percent error 40.70
# Epoch    13, train loss 0.361494, train error 11.90,  val loss 1.220488, percent error 40.80
# Epoch    14, train loss 0.305992, train error 9.88,  val loss 1.178789, percent error 40.10
# Epoch    15, train loss 0.260231, train error 7.78,  val loss 1.238580, percent error 39.20
# Epoch    16, train loss 0.233811, train error 6.93,  val loss 1.278398, percent error 38.30
# Epoch    17, train loss 0.202969, train error 5.62,  val loss 1.233011, percent error 37.70
# Epoch    18, train loss 0.197597, train error 6.30,  val loss 1.315851, percent error 38.30
# Epoch    19, train loss 0.152413, train error 3.80,  val loss 1.348002, percent error 39.00
# Epoch    20, train loss 0.090309, train error 0.82,  val loss 1.294592, percent error 38.50
# Epoch    21, train loss 0.073267, train error 0.50,  val loss 1.282906, percent error 39.00
# Epoch    22, train loss 0.060133, train error 0.05,  val loss 1.287983, percent error 37.90
# Epoch    23, train loss 0.055490, train error 0.12,  val loss 1.331162, percent error 37.20
# Epoch    24, train loss 0.049709, train error 0.10,  val loss 1.350595, percent error 38.90
# Epoch    25, train loss 0.044200, train error 0.03,  val loss 1.381698, percent error 37.70
# Epoch    26, train loss 0.041441, train error 0.03,  val loss 1.396417, percent error 37.60
# Epoch    27, train loss 0.038064, train error 0.03,  val loss 1.408893, percent error 38.90
# Epoch    28, train loss 0.035929, train error 0.00,  val loss 1.426048, percent error 38.30
# Epoch    29, train loss 0.034347, train error 0.03,  val loss 1.448402, percent error 39.20
# Epoch    30, train loss 0.030153, train error 0.00,  val loss 1.446530, percent error 38.10
# Epoch    31, train loss 0.029175, train error 0.00,  val loss 1.473785, percent error 38.20
# Epoch    32, train loss 0.026381, train error 0.00,  val loss 1.476855, percent error 38.50
# Epoch    33, train loss 0.024518, train error 0.00,  val loss 1.494462, percent error 37.90
# Epoch    34, train loss 0.023329, train error 0.00,  val loss 1.529170, percent error 39.30
# Epoch    35, train loss 0.021826, train error 0.00,  val loss 1.526513, percent error 38.20
# Epoch    36, train loss 0.020591, train error 0.00,  val loss 1.536087, percent error 38.60
# Epoch    37, train loss 0.019747, train error 0.00,  val loss 1.557207, percent error 38.70
# Epoch    38, train loss 0.018987, train error 0.00,  val loss 1.573321, percent error 39.00
# Epoch    39, train loss 0.017959, train error 0.00,  val loss 1.569948, percent error 38.10
# Epoch    40, train loss 0.017237, train error 0.00,  val loss 1.575140, percent error 38.90
# Epoch    41, train loss 0.016780, train error 0.00,  val loss 1.581471, percent error 38.70
# Epoch    42, train loss 0.016503, train error 0.00,  val loss 1.588863, percent error 38.50
# Epoch    43, train loss 0.016066, train error 0.00,  val loss 1.594255, percent error 39.10
# Epoch    44, train loss 0.015708, train error 0.00,  val loss 1.597167, percent error 38.70
# Epoch    45, train loss 0.015463, train error 0.00,  val loss 1.603002, percent error 38.50
# Epoch    46, train loss 0.015107, train error 0.00,  val loss 1.606033, percent error 38.30
# Epoch    47, train loss 0.014853, train error 0.00,  val loss 1.610595, percent error 38.60
# Epoch    48, train loss 0.014589, train error 0.00,  val loss 1.616642, percent error 38.80
# Epoch    49, train loss 0.014234, train error 0.00,  val loss 1.620540, percent error 38.70
# Epoch    50, train loss 0.014030, train error 0.00,  val loss 1.627147, percent error 38.90
# Epoch    51, train loss 0.013739, train error 0.00,  val loss 1.632437, percent error 38.40
# Epoch    52, train loss 0.013486, train error 0.00,  val loss 1.635988, percent error 38.20
# Epoch    53, train loss 0.013272, train error 0.00,  val loss 1.639418, percent error 38.40
# Epoch    54, train loss 0.012977, train error 0.00,  val loss 1.642913, percent error 38.70
# Epoch    55, train loss 0.012768, train error 0.00,  val loss 1.651874, percent error 38.70
# Epoch    56, train loss 0.012567, train error 0.00,  val loss 1.652099, percent error 38.30
# Epoch    57, train loss 0.012337, train error 0.00,  val loss 1.660666, percent error 38.60
# Epoch    58, train loss 0.012134, train error 0.00,  val loss 1.662620, percent error 38.80
# Epoch    59, train loss 0.011926, train error 0.00,  val loss 1.664773, percent error 38.70
# Epoch    60, train loss 0.011805, train error 0.00,  val loss 1.668655, percent error 38.40
# Epoch    61, train loss 0.011716, train error 0.00,  val loss 1.669371, percent error 38.70
# Epoch    62, train loss 0.011609, train error 0.00,  val loss 1.671157, percent error 38.60
# Epoch    63, train loss 0.011508, train error 0.00,  val loss 1.675138, percent error 38.60
# Epoch    64, train loss 0.011429, train error 0.00,  val loss 1.677565, percent error 38.40
# Epoch    65, train loss 0.011334, train error 0.00,  val loss 1.679730, percent error 38.50
# Epoch    66, train loss 0.011240, train error 0.00,  val loss 1.679660, percent error 38.40
# Epoch    67, train loss 0.011155, train error 0.00,  val loss 1.682780, percent error 38.50
# Epoch    68, train loss 0.011078, train error 0.00,  val loss 1.684156, percent error 38.60
# Epoch    69, train loss 0.010985, train error 0.00,  val loss 1.686668, percent error 38.40
# Epoch    70, train loss 0.010900, train error 0.00,  val loss 1.689858, percent error 38.40
# Epoch    71, train loss 0.010822, train error 0.00,  val loss 1.689067, percent error 38.50
# Epoch    72, train loss 0.010740, train error 0.00,  val loss 1.693283, percent error 38.50
# Epoch    73, train loss 0.010661, train error 0.00,  val loss 1.695133, percent error 38.30
# Epoch    74, train loss 0.010579, train error 0.00,  val loss 1.697071, percent error 38.60
# Epoch    75, train loss 0.010503, train error 0.00,  val loss 1.697792, percent error 38.60
# Epoch    76, train loss 0.010425, train error 0.00,  val loss 1.699576, percent error 38.30
# Epoch    77, train loss 0.010343, train error 0.00,  val loss 1.701744, percent error 38.40
# Epoch    78, train loss 0.010270, train error 0.00,  val loss 1.704197, percent error 38.30
# Epoch    79, train loss 0.010196, train error 0.00,  val loss 1.706744, percent error 38.40
# Epoch    80, train loss 0.010150, train error 0.00,  val loss 1.706615, percent error 38.40
# Epoch    81, train loss 0.010113, train error 0.00,  val loss 1.707760, percent error 38.40
# Epoch    82, train loss 0.010077, train error 0.00,  val loss 1.708060, percent error 38.50
# Epoch    83, train loss 0.010040, train error 0.00,  val loss 1.709010, percent error 38.40
# Epoch    84, train loss 0.010006, train error 0.00,  val loss 1.710361, percent error 38.40
# Epoch    85, train loss 0.009969, train error 0.00,  val loss 1.710547, percent error 38.40
# Epoch    86, train loss 0.009934, train error 0.00,  val loss 1.712695, percent error 38.40
# Epoch    87, train loss 0.009901, train error 0.00,  val loss 1.712835, percent error 38.50
# Epoch    88, train loss 0.009865, train error 0.00,  val loss 1.713723, percent error 38.60
# Epoch    89, train loss 0.009831, train error 0.00,  val loss 1.715121, percent error 38.50
# Epoch    90, train loss 0.009796, train error 0.00,  val loss 1.715446, percent error 38.60
# Epoch    91, train loss 0.009764, train error 0.00,  val loss 1.717156, percent error 38.40
# Epoch    92, train loss 0.009729, train error 0.00,  val loss 1.716870, percent error 38.50
# Epoch    93, train loss 0.009693, train error 0.00,  val loss 1.718560, percent error 38.50
# Epoch    94, train loss 0.009661, train error 0.00,  val loss 1.719293, percent error 38.50
# Epoch    95, train loss 0.009628, train error 0.00,  val loss 1.719634, percent error 38.40
# Epoch    96, train loss 0.009595, train error 0.00,  val loss 1.720509, percent error 38.30
# Epoch    97, train loss 0.009563, train error 0.00,  val loss 1.720793, percent error 38.60
# Epoch    98, train loss 0.009530, train error 0.00,  val loss 1.723119, percent error 38.50
# Epoch    99, train loss 0.009497, train error 0.00,  val loss 1.723658, percent error 38.40
